# %% [markdown]
# # Discussion Section Oct 3

# %% [markdown]
# ## Archive Exploration
# 1. What is this data about?
#
# This data is for arthropod prey of species in California drylands
#
# 2. Is this data collected in-situ by the authors or is it a synthesis of multiple datasets?
#
# Synthesis of multiple datasets
#
# 3. During what time frame were the observations in the dataset collected?
#
# Between 1945 and 2022
#
# 4. Does this dataset come with an associated metadata file?
#
# Yes!
#
# 5. Does the dataset contain sensitive data?
#
# No

# %% [markdown]
# ## Metadata Explorations

# %%
# Import libraries
import pandas as pd

# %%
# Access metadata from repository
df = pd.read_csv('https://knb.ecoinformatics.org/knb/d1/mn/v2/object/urn%3Auuid%3A3baf7289-bf90-4db3-ad11-58785c09b26e')

# %%
df.head()
# Out:
#   attribute                            description
# 0     class   taxonomic class of observed organism
# 1     order   taxonomic order of observed organism
# 2    family  taxonomic family of observed organism
# 3     genus                             genus name
# 4   species               full latin binomial name

# %% [markdown]
# ## Data Loading

# %%
prey = pd.read_csv('https://knb.ecoinformatics.org/knb/d1/mn/v2/object/urn%3Auuid%3A23d42528-1048-45d4-85d1-7e13b666e744')

# %%
# What is the type of the prey variable?
type(prey)
# Out:
# pandas.core.frame.DataFrame

# %%
# Prey is a dataframe

# %%
prey.head()
# Out:
#           class        order           family          genus  \
# 0       Insecta      Odonata     Libellulidae      Sympetrum
# 1  Malacostraca      Isopoda  Armadillidiidae  Armadillidium
# 2       Insecta  Hymenoptera           Apidae         Bombus
# 3       Insecta  Hymenoptera           Apidae           Apis
# 4       Insecta    Hemiptera        Lygaeidae     Oncopeltus
#
#                  species        lat        long             eventDate   day  \
# 0    Sympetrum corruptum  37.173971 -121.856329  2020-09-29T08:24:00Z  29.0
# 1  Armadillidium vulgare  37.688580 -122.436608  2021-12-04T14:49:59Z   4.0
# 2    Bombus vosnesenskii  33.774911 -116.679713  2021-06-18T08:52:00Z  18.0
# 3         Apis mellifera  32.848001 -117.050126  2016-04-17T09:28:00Z  17.0
# 4   Oncopeltus fasciatus  32.739453 -117.133980  2019-04-06T18:44:31Z   6.0
#
#    month  ...         bio4        bio5       bio6        bio7        bio8  \
# ...

# %%
# There are 40 columns. Many of the columns are not very descriptive (bio4, bio5, etc.). There is also a column with camel case

# %%
pd.set_option("display.max.columns", None)
prey.head()
# Out:
#           class        order           family          genus  \
# 0       Insecta      Odonata     Libellulidae      Sympetrum
# 1  Malacostraca      Isopoda  Armadillidiidae  Armadillidium
# 2       Insecta  Hymenoptera           Apidae         Bombus
# 3       Insecta  Hymenoptera           Apidae           Apis
# 4       Insecta    Hemiptera        Lygaeidae     Oncopeltus
#
#                  species        lat        long             eventDate   day  \
# 0    Sympetrum corruptum  37.173971 -121.856329  2020-09-29T08:24:00Z  29.0
# 1  Armadillidium vulgare  37.688580 -122.436608  2021-12-04T14:49:59Z   4.0
# 2    Bombus vosnesenskii  33.774911 -116.679713  2021-06-18T08:52:00Z  18.0
# 3         Apis mellifera  32.848001 -117.050126  2016-04-17T09:28:00Z  17.0
# 4   Oncopeltus fasciatus  32.739453 -117.133980  2019-04-06T18:44:31Z   6.0
#
#    month  year institutionCode  coordinateUncertaintyInMeters  \
# 0    9.0  2020     iNaturalist                          684.0
# ...

# %%
# `pd.set_option("display.max.columns", None)` allows you to see all 40 of the column names instead of just the first and last 10

# %% [markdown]
# ## pd.DataFrame Preliminary Exploration

# %%
# `head()` shows the first 5 rows of the dataframe
prey.head()
# Out:
#           class        order           family          genus  \
# 0       Insecta      Odonata     Libellulidae      Sympetrum
# 1  Malacostraca      Isopoda  Armadillidiidae  Armadillidium
# 2       Insecta  Hymenoptera           Apidae         Bombus
# 3       Insecta  Hymenoptera           Apidae           Apis
# 4       Insecta    Hemiptera        Lygaeidae     Oncopeltus
#
#                  species        lat        long             eventDate   day  \
# 0    Sympetrum corruptum  37.173971 -121.856329  2020-09-29T08:24:00Z  29.0
# 1  Armadillidium vulgare  37.688580 -122.436608  2021-12-04T14:49:59Z   4.0
# 2    Bombus vosnesenskii  33.774911 -116.679713  2021-06-18T08:52:00Z  18.0
# 3         Apis mellifera  32.848001 -117.050126  2016-04-17T09:28:00Z  17.0
# 4   Oncopeltus fasciatus  32.739453 -117.133980  2019-04-06T18:44:31Z   6.0
#
#    month  year institutionCode  coordinateUncertaintyInMeters  \
# 0    9.0  2020     iNaturalist                          684.0
# ...

# %%
# `tail()` shows the last 5 rows of the dataframe
prey.tail()
# Out:
#           class        order       family         genus  \
# 111151  Insecta  Hymenoptera   Formicidae  Pogonomyrmex
# 111152  Insecta  Hymenoptera   Formicidae  Pogonomyrmex
# 111153  Insecta  Hymenoptera   Formicidae    Liometopum
# 111154  Insecta  Hymenoptera   Formicidae  Pogonomyrmex
# 111155  Insecta  Lepidoptera  Nymphalidae       Vanessa
#
#                           species        lat        long  \
# 111151  Pogonomyrmex californicus  33.660853 -115.721380
# 111152  Pogonomyrmex californicus  35.933333 -116.716667
# 111153     Liometopum occidentale  34.156833 -118.726833
# 111154  Pogonomyrmex californicus  32.989167 -116.658500
# 111155             Vanessa cardui  36.251400 -117.731400
#
#                    eventDate   day  month  year institutionCode  \
# 111151  1980-04-10T00:00:00Z  10.0    4.0  1980             MCZ
# 111152  1998-03-26T00:00:00Z  26.0    3.0  1998             MCZ
# 111153  2010-05-21T00:00:00Z  21.0    5.0  2010             MCZ
# ...

# %%
# `info()` shows the column names, number of non null values and the type of column
prey.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 111156 entries, 0 to 111155
# Data columns (total 40 columns):
#  #   Column                         Non-Null Count   Dtype
# ---  ------                         --------------   -----
#  0   class                          111156 non-null  object
#  1   order                          111054 non-null  object
#  2   family                         111156 non-null  object
#  3   genus                          111156 non-null  object
#  4   species                        111156 non-null  object
#  5   lat                            111156 non-null  float64
#  6   long                           111156 non-null  float64
#  7   eventDate                      111156 non-null  object
#  8   day                            110998 non-null  float64
#  9   month                          111127 non-null  float64
#  10  year                           111156 non-null  int64
#  11  institutionCode                110414 non-null  object
# ...

# %%
# `nunique()` shows the count of unique observations for each column
prey.nunique()
# Out:
# class                                 4
# order                                18
# family                               63
# genus                                92
# species                              97
# lat                               91909
# long                              91965
# eventDate                        102140
# day                                  31
# month                                12
# year                                 77
# institutionCode                      77
# coordinateUncertaintyInMeters      4450
# basisOfRecord                         4
# individualCount                      42
# datasetKey                           88
# ID                               111156
# bio1                              11778
# bio10                             11981
# bio11                             11803
# bio12                             12117
# bio13                             12020
# bio14                              4586
# ...

# %%
# Change the default value of head()
prey.head(10)
# Out:
#           class        order           family          genus  \
# 0       Insecta      Odonata     Libellulidae      Sympetrum
# 1  Malacostraca      Isopoda  Armadillidiidae  Armadillidium
# 2       Insecta  Hymenoptera           Apidae         Bombus
# 3       Insecta  Hymenoptera           Apidae           Apis
# 4       Insecta    Hemiptera        Lygaeidae     Oncopeltus
# 5       Insecta      Diptera        Syrphidae     Allograpta
# 6       Insecta   Orthoptera        Acrididae   Schistocerca
# 7       Insecta  Hymenoptera           Apidae           Apis
# 8       Insecta  Hymenoptera           Apidae           Apis
# 9       Insecta  Lepidoptera      Nymphalidae        Vanessa
#
#                  species        lat        long             eventDate   day  \
# 0    Sympetrum corruptum  37.173971 -121.856329  2020-09-29T08:24:00Z  29.0
# 1  Armadillidium vulgare  37.688580 -122.436608  2021-12-04T14:49:59Z   4.0
# ...

# %%
# `shape` shows the number of rows and columns
prey.shape
# Out:
# (111156, 40)

# %%
# `columns` shows the different names of all the columns
prey.columns
# Out:
# Index(['class', 'order', 'family', 'genus', 'species', 'lat', 'long',
#        'eventDate', 'day', 'month', 'year', 'institutionCode',
#        'coordinateUncertaintyInMeters', 'basisOfRecord', 'individualCount',
#        'datasetKey', 'ID', 'bio1', 'bio10', 'bio11', 'bio12', 'bio13', 'bio14',
#        'bio15', 'bio16', 'bio17', 'bio18', 'bio19', 'bio2', 'bio3', 'bio4',
#        'bio5', 'bio6', 'bio7', 'bio8', 'bio9', 'dist', 'dem90_hf', 'lc_class',
#        'ndvi'],
#       dtype='object')

# %%
# `dtypes` shows the type of variables in each column (object, float, int...)
prey.dtypes
# Out:
# class                             object
# order                             object
# family                            object
# genus                             object
# species                           object
# lat                              float64
# long                             float64
# eventDate                         object
# day                              float64
# month                            float64
# year                               int64
# institutionCode                   object
# coordinateUncertaintyInMeters    float64
# basisOfRecord                     object
# individualCount                  float64
# datasetKey                        object
# ID                                 int64
# bio1                             float64
# bio10                            float64
# bio11                            float64
# bio12                            float64
# bio13                            float64
# bio14                            float64
# ...

# %% [markdown]
# ## Update column names

# %%
# Change the column names of institutionCode and datasetKey to institution_code and dataset_key
prey = prey.rename(columns = {'institutionCode' : 'institution_code', 'datasetKey' : 'dataset_key'})

# Confirm columns are renamed
prey.head()
# Out:
#           class        order           family          genus  \
# 0       Insecta      Odonata     Libellulidae      Sympetrum
# 1  Malacostraca      Isopoda  Armadillidiidae  Armadillidium
# 2       Insecta  Hymenoptera           Apidae         Bombus
# 3       Insecta  Hymenoptera           Apidae           Apis
# 4       Insecta    Hemiptera        Lygaeidae     Oncopeltus
#
#                  species        lat        long             eventDate   day  \
# 0    Sympetrum corruptum  37.173971 -121.856329  2020-09-29T08:24:00Z  29.0
# 1  Armadillidium vulgare  37.688580 -122.436608  2021-12-04T14:49:59Z   4.0
# 2    Bombus vosnesenskii  33.774911 -116.679713  2021-06-18T08:52:00Z  18.0
# 3         Apis mellifera  32.848001 -117.050126  2016-04-17T09:28:00Z  17.0
# 4   Oncopeltus fasciatus  32.739453 -117.133980  2019-04-06T18:44:31Z   6.0
#
#    month  year institution_code  coordinateUncertaintyInMeters  \
# 0    9.0  2020      iNaturalist                          684.0
# ...
